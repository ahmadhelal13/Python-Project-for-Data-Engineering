# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# -   Collect exchange rate data using an API
# -   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
# 1. Open the url : https://exchangeratesapi.io/ and click on **Get Free API Key**.
# 2. Subscribe for Free plan and Sign-in with the Google Account.
# 3. Once the account is created you will be redirected to https://apilayer.com website.
# 2. Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png">
#
# 3. Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
#  <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Write your code here
url = "http://api.exchangeratesapi.io/v1/latest?access_key=64cdf2f1e7f5d54d9bf9600a982d263c" #Make sure to change ******* to your API key.
content = requests.get(url)
print(content)
# Out:
# <Response [200]>

# %%
content.json()
# Out:
# {'success': True,
#  'timestamp': 1685981823,
#  'base': 'EUR',
#  'date': '2023-06-05',
#  'rates': {'AED': 3.937043,
#   'AFN': 93.789659,
#   'ALL': 108.743427,
#   'AMD': 415.122004,
#   'ANG': 1.932177,
#   'AOA': 639.388556,
#   'ARS': 260.031217,
#   'AUD': 1.617595,
#   'AWG': 1.929405,
#   'AZN': 1.815144,
#   'BAM': 1.960861,
#   'BBD': 2.164587,
#   'BDT': 115.501328,
#   'BGN': 1.958474,
#   'BHD': 0.404176,
#   'BIF': 3028.093287,
#   'BMD': 1.071891,
#   'BND': 1.449609,
#   'BOB': 7.408466,
#   'BRL': 5.271887,
#   'BSD': 1.072067,
#   'BTC': 4.1327333e-05,
#   'BTN': 88.550269,
#   'BWP': 14.666537,
#   'BYN': 2.70611,
#   'BYR': 21009.072011,
#   'BZD': 2.161078,
#   'CAD': 1.438419,
#   'CDF': 2492.147389,
#   'CHF': 0.970801,
#   'CLF': 0.030942,
#   'CLP': 853.77229,
#   'CNY': 7.616435,
#   'COP': 4608.833016,
#   'CRC': 576.815602,
#   'CUC': 1.071891,
#   'CUP': 28.405123,
#   'CVE': 110.673143,
#   'CZK': 23.531978,
#   'DJF': 190.891574,
#   'DKK': 7.449045,
#   'DOP': 58.522552,
#   'DZD': 146.232797,
#   'EGP': 33.124735,
#   'ERN': 16.078371,
#   'ETB': 58.267953,
#   'EUR': 1,
#   'FJD': 2.425315,
#   'FKP': 0.860946,
#   'GBP': 0.861597,
#   'GEL': 2.797807,
#   'GGP': 0.860946,
#   'GHS': 12.085541,
#   'GIP': 0.860946,
#   'GMD': 63.7811,
#   'GNF': 9278.292569,
#   'GTQ': 8.395058,
#   'GYD': 226.755808,
#   'HKD': 8.401083,
#   'HNL': 26.497036,
#   'HRK': 7.443579,
#   'HTG': 150.628756,
#   'HUF': 368.831442,
#   'IDR': 15901.241378,
#   'ILS': 4.009072,
#   'IMP': 0.860946,
#   'INR': 88.442511,
#   'IQD': 1404.177772,
#   'IRR': 45367.804807,
#   'ISK': 150.965138,
#   'JEP': 0.860946,
#   'JMD': 166.006187,
#   'JOD': 0.761152,
#   'JPY': 149.645707,
#   'KES': 148.781552,
#   'KGS': 93.766895,
#   'KHR': 4417.264854,
#   'KMF': 493.016406,
#   'KPW': 964.702036,
#   'KRW': 1395.516854,
#   'KWD': 0.329832,
#   'KYD': 0.893448,
#   'KZT': 480.582747,
#   'LAK': 19267.248453,
#   'LBP': 16351.703934,
#   'LKR': 311.985198,
#   'LRD': 181.675444,
#   'LSL': 20.923476,
#   'LTL': 3.165017,
#   'LVL': 0.648376,
#   'LYD': 5.188083,
#   'MAD': 10.92847,
#   'MDL': 19.1052,
#   'MGA': 4732.400735,
#   'MKD': 61.680918,
#   'MMK': 2251.415667,
#   'MNT': 3696.986643,
#   'MOP': 8.655442,
#   'MRO': 382.665056,
#   'MUR': 48.877101,
#   'MVR': 16.453773,
#   'MWK': 1096.54548,
#   'MXN': 18.725461,
#   'MYR': 4.90658,
#   'MZN': 67.79695,
#   'NAD': 20.923332,
#   'NGN': 495.213502,
#   'NIO': 39.187883,
#   'NOK': 11.816315,
#   'NPR': 141.680269,
#   'NZD': 1.762184,
#   'OMR': 0.412706,
#   'PAB': 1.072117,
#   'PEN': 3.949387,
#   'PGK': 3.772918,
#   'PHP': 60.223683,
#   'PKR': 306.158988,
#   'PLN': 4.474047,
#   'PYG': 7735.324814,
#   'QAR': 3.902765,
#   'RON': 4.964897,
#   'RSD': 117.232719,
#   'RUB': 86.610117,
#   'RWF': 1213.917043,
#   'SAR': 4.019749,
#   'SBD': 8.940631,
#   'SCR': 14.852119,
#   'SDG': 644.206878,
#   'SEK': 11.630065,
#   'SGD': 1.446051,
#   'SHP': 1.304224,
#   'SLE': 24.224681,
#   'SLL': 21169.855856,
#   'SOS': 609.37345,
#   'SRD': 40.007811,
#   'STD': 22185.988443,
#   'SVC': 9.380472,
#   'SYP': 2693.164525,
#   'SZL': 20.923299,
#   'THB': 37.265375,
#   'TJS': 11.707562,
#   'TMT': 3.762339,
#   'TND': 3.314271,
#   'TOP': 2.542902,
#   'TRY': 22.777393,
#   'TTD': 7.267095,
#   'TWD': 32.909526,
#   'TZS': 2538.239132,
#   'UAH': 39.597744,
#   'UGX': 4004.33473,
#   'USD': 1.071891,
#   'UYU': 41.608551,
#   'UZS': 12257.078134,
#   'VEF': 2830475.385793,
#   'VES': 28.334521,
#   'VND': 25189.448585,
#   'VUV': 127.985644,
#   'WST': 2.943113,
#   'XAF': 657.685089,
#   'XAG': 0.045471,
#   'XAU': 0.000547,
#   'XCD': 2.89684,
#   'XDR': 0.803612,
#   'XOF': 653.316134,
#   'XPF': 119.78389,
#   'YER': 268.347953,
#   'ZAR': 20.675393,
#   'ZMK': 9648.310075,
#   'ZMW': 21.281919,
#   'ZWL': 345.148603}}

# %% [markdown]
# ### Save as DataFrame
#
#  <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Turn the data into a dataframe
df = pd.DataFrame(content.json())
df.head()
# Out:
#      success   timestamp base        date       rates
# AED     True  1685981103  EUR  2023-06-05    3.937319
# AFN     True  1685981103  EUR  2023-06-05   93.800061
# ALL     True  1685981103  EUR  2023-06-05  108.750240
# AMD     True  1685981103  EUR  2023-06-05  415.149084
# ANG     True  1685981103  EUR  2023-06-05    1.932302

# %%
# Drop unnescessary columns
df.drop(columns=['success','timestamp'],inplace=True)

# %%
df
# Out:
#     base        date        rates
# AED  EUR  2023-06-05     3.937319
# AFN  EUR  2023-06-05    93.800061
# ALL  EUR  2023-06-05   108.750240
# AMD  EUR  2023-06-05   415.149084
# ANG  EUR  2023-06-05     1.932302
# ..   ...         ...          ...
# YER  EUR  2023-06-05   268.365356
# ZAR  EUR  2023-06-05    20.671480
# ZMK  EUR  2023-06-05  9648.938777
# ZMW  EUR  2023-06-05    21.283299
# ZWL  EUR  2023-06-05   345.170978
#
# [170 rows x 3 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
df.to_csv(".\exchange_rates_1")

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# | | Rates |
# | ------- | ------- |
# |  AED| 4.398618    |
# |  AFN| 92.917693   |
# |  ALL| 123.099093  |
# |  AMD| 621.935674  |
# |  ANG| 2.149648    |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url|
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR    |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork899-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
